# %% [markdown]
# # AML s26 - KNN Classifier

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ### Load and visualize data

# %%
df = pd.read_csv('knn_dataset_A.csv')

print("Shape:", df.shape)
print(df.head(5))
# Out:
# Shape: (500, 3)
#    feature_1  feature_2 label
# 0   2.736928   1.380405     B
# 1   2.239011   0.167232     B
# 2   1.661672  -0.427913     B
# 3  -1.458047   3.325565     A
# 4   2.321741  -0.058554     B

# %% [markdown]
# ### Generate class statistics for the complete data set

# %%
df_y = df.label
df_y.value_counts()
# Out:
# label
# A    240
# B    150
# C     75
# D     35
# Name: count, dtype: int64

# %% [markdown]
# ### Get the feature vectors

# %%
df_X = df.drop('label', axis=1)
df_X.head(5)
# Out:
#    feature_1  feature_2
# 0   2.736928   1.380405
# 1   2.239011   0.167232
# 2   1.661672  -0.427913
# 3  -1.458047   3.325565
# 4   2.321741  -0.058554

# %% [markdown]
# ### Train-Test split
#
# Note we have options ... this is important! Why?

# %%
naive = False

state = None #962

if naive:
    (X_train, X_test, y_train, y_test) = train_test_split(np.asarray(df_X), df_y,                test_size=0.3, random_state=state)
else:
    (X_train, X_test, y_train, y_test) = train_test_split(np.asarray(df_X), df_y, stratify=df_y, test_size=0.3, random_state=state)

y_test.value_counts()
 
#y_train.value_counts()
# Out:
# label
# A    72
# B    45
# C    23
# D    10
# Name: count, dtype: int64

# %% [markdown]
# ### Standardize features

# %%
scaler = StandardScaler(with_mean=True, with_std=True, copy=True)

scaler.fit(X_train)
X_train_std = scaler.transform(X_train)
X_test_std = scaler.transform(X_test)

# %% [markdown]
# ### Train KNN classifier and get test error rate

# %%
k=15
knn1 = KNeighborsClassifier(n_neighbors=k)

y_pred = knn1.fit(X_train_std, y_train).predict(X_test_std)

print(f"Error rate:  {np.mean(y_test != y_pred):.4f}")
# Out:
# Error rate:  0.2067

# %% [markdown]
# ### Generate a confusion matrix to show misclassification per category

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[60  7  5  0]
#  [ 8 32  0  5]
#  [ 0  0 22  1]
#  [ 0  3  2  5]]

# %% [markdown]
# ### Now with nicer looks ...

# %%
disp = ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
plt.title("Confusion matrix (counts)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Now normalized ...

# %%
disp = ConfusionMatrixDisplay.from_predictions(y_test, y_pred, normalize="true", values_format=".2f", cmap="Blues", colorbar=True)

disp.ax_.set_title("Confusion matrix (normalized by true class)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Get the test error as a function of K

# %%
all_k =[]
all_err=[]

max_K = 30
for K in range(1,max_K+1):
    knn = KNeighborsClassifier(n_neighbors=K)
    
    y_pred = knn.fit(X_train_std, y_train).predict(X_test_std)
    error = np.mean(y_test != y_pred)
    print(f"k: {K}   Error rate:  {error:.4f}")
    
    all_k.append(K)
    all_err.append(error)
# Out:
# k: 1   Error rate:  0.2133
# k: 2   Error rate:  0.2067
# k: 3   Error rate:  0.2133
# k: 4   Error rate:  0.1867
# k: 5   Error rate:  0.1733
# k: 6   Error rate:  0.1800
# k: 7   Error rate:  0.1733
# k: 8   Error rate:  0.1667
# k: 9   Error rate:  0.1667
# k: 10   Error rate:  0.1867
# k: 11   Error rate:  0.1867
# k: 12   Error rate:  0.1933
# k: 13   Error rate:  0.2000
# k: 14   Error rate:  0.2000
# k: 15   Error rate:  0.2067
# k: 16   Error rate:  0.1933
# k: 17   Error rate:  0.2067
# k: 18   Error rate:  0.2000
# k: 19   Error rate:  0.1867
# k: 20   Error rate:  0.1933
# k: 21   Error rate:  0.1933
# k: 22   Error rate:  0.1867
# k: 23   Error rate:  0.1867
# k: 24   Error rate:  0.1867
# k: 25   Error rate:  0.1800
# k: 26   Error rate:  0.1867
# k: 27   Error rate:  0.1867
# k: 28   Error rate:  0.1933
# k: 29   Error rate:  0.1733
# k: 30   Error rate:  0.1933

# %% [markdown]
# ## Plot test error rate as a function of K

# %%
plt.figure(1, figsize=(10, 6))

plt.plot(all_k, all_err, linewidth=2, label="Test Error", color='blue')
plt.xlabel("K", fontsize=12)
plt.ylabel("Error", fontsize=12)
plt.title(f"Classifier (KNN)", fontsize=14)
plt.legend(fontsize=10)
plt.grid(True, alpha=0.3)
plt.xticks(np.arange(1, max_K+1, 1))
plt.tight_layout()
plt.show()
