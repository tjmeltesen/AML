# %%
import numpy as np

# %%
def rotation_matrix(alpha, beta, gamma):
    alpha = np.deg2rad(alpha)
    beta = np.deg2rad(beta)
    gamma = np.deg2rad(gamma)
    R_X = np.matrix([[1,0,0],[0,np.cos(alpha), -np.sin(alpha)], [0,np.sin(alpha), np.cos(alpha)]])
    #print(R_X)
    R_Y = np.matrix([[np.cos(beta),0,np.sin(beta)],[0,1,0],[-np.sin(beta),0,np.cos(beta)]])
    #print(R_Y)
    R_Z = np.matrix([[np.cos(gamma), -np.sin(gamma),0],[np.sin(gamma), np.cos(gamma),0],[0,0,1]])
    #print(R_Z)

    A = np.matmul(R_X,R_Y)

    R = np.matmul(R_Z,A)
    return R

result_matrix =rotation_matrix(60, 30, 45)
print(result_matrix)
# Out:
# [[ 0.30618622 -0.35355339  0.88388348]
#  [ 0.91855865  0.35355339 -0.1767767 ]
#  [-0.25        0.8660254   0.4330127 ]]
